# %% [markdown]
# 1.   Use Copilot to identify and summarize missing values in the dataset.
#
# -  | Column     | Missing Values      | Problem Caused                        |
# | ---------- | ------------------- | ------------------------------------- |
# | Region     | Yes (multiple rows) | Region analysis not reliable          |
# | Category   | Yes                 | Product category insights affected    |
# | Units Sold | Yes                 | Sales totals incorrect                |
# | Unit Price | Yes                 | Revenue & profit cannot be calculated |
#
#
# 2.  Use Copilot to fill missing values in the region and category column.
#
# - | Order ID | Country   | Filled Region | Reason                                    |
# | -------- | --------- | ------------- | ----------------------------------------- |
# | ORD0010  | USA       | **East**      | USA mostly East/West → East more frequent |
# | ORD0018  | India     | **West**      | India often West/South → picked frequent  |
# | ORD0031  | India     | **West**      | Same logic                                |
# | ORD0050  | Germany   | **North**     | Germany appears North often               |
# | ORD0064  | USA       | **East**      | Pattern match                             |
# | ORD0118  | Germany   | **West**      | Germany commonly West                     |
# | ORD0122  | Australia | **South**     | Balanced → chose common                   |
# | ORD0332  | India     | **West**      | Most frequent                             |
# | ORD0347  | Germany   | **West**      | Pattern                                   |
#
#
# 3.  Fill missing numeric values in the unit sold and unit price column.
#
# -  | Order ID | Filled Value |
# | -------- | ------------ |
# | ORD0039  | 260          |
# | ORD0131  | 260          |
# | ORD0200  | 260          |
# | ORD0228  | 260          |
# | ORD0251  | 260          |
# | ORD0289  | 260          |
# | ORD0294  | 260          |
# | ORD0314  | 260          |
# | ORD0317  | 260          |
# | ORD0328  | 260          |
#
#
# | Order ID | Filled Value |
# | -------- | ------------ |
# | ORD0028  | 250          |
# | ORD0037  | 250          |
# | ORD0045  | 250          |
# | ORD0080  | 250          |
# | ORD0092  | 250          |
# | ORD0157  | 250          |
# | ORD0257  | 250          |
# | ORD0261  | 250          |
# | ORD0288  | 250          |
# | ORD0308  | 250          |
#
#
# 4.  Create a new calculated column total revenue.
#
# -  | Order ID | Units Sold | Unit Price | Total Revenue |
# | -------- | ---------- | ---------- | ------------- |
# | ORD0001  | 235        | 152.92     | 35,935.20     |
# | ORD0002  | 341        | 467.92     | 159,960.72    |
# | ORD0003  | 179        | 473.94     | 84,835.26     |
#
# To create a new calculated column: Total Revenue, you just need this simple formula:
#
#  Formula for Total Revenue
# Total Revenue=Units Sold×Unit Price
#
# In Excel
#
# Assuming:
#
# Units Sold → Column H
# Unit Price → Column I
#
# Enter this in a new column (say Column K):
#
# =H2 * I2
#
# 5.  Use Copilot to find the total price of Order ID = ‘ORD0123’.
#
# -  Step 1: Extract Data for ORD0123
#
# From your dataset:
#
# Units Sold = 46
# Unit Price = 344.55
#  Step 2: Apply Formula
# Total Revenue=Units Sold×Unit Price
# =46×344.55=15,849.30
#   Final Answer
#
#  Total Revenue for ORD0123 = 15,849.30
